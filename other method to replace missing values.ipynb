# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data2.csv")
df
# Out:
#          Name   Python Machine Learning      Age       AI      NLP       Cv
# 0      Sakshi       90                ?       23       90        ?       23
# 1      rajesh  missing               89      NaN  missing       89      NaN
# 2      pratik       78               78        ?       78       78        ?
# 3       mayur      NaN              NaN  missing      NaN      NaN  missing
# 4     harshit  missing              NaN       21  missing      NaN       21
# 5       yusra       65               56       22       65       56       22
# 6       omkar       45               67        ?       45       67        ?
# 7   tejashree       80               45       24       80       45       24
# 8      khushi       70               67  missing       70       67  missing
# 9    vrishali      NaN              NaN       22      NaN      NaN       22
# 10     mahesh        $          missing       22        ?        ?       80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            14 non-null     object
#  2   Machine Learning  12 non-null     object
#  3   Age               18 non-null     object
#  4   AI                14 non-null     object
#  5   NLP               13 non-null     object
#  6   Cv                16 non-null     object
# dtypes: object(7)
# memory usage: 1.2+ KB

# %%
df=pd.read_csv("data2.csv",na_values=["?","missing","$","*",",","/"])

# %%
df
# Out:
#          Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0      Sakshi    90.0               NaN  23.0  90.0   NaN  23.0
# 1      rajesh     NaN              89.0   NaN   NaN  89.0   NaN
# 2      pratik    78.0              78.0   NaN  78.0  78.0   NaN
# 3       mayur     NaN               NaN   NaN   NaN   NaN   NaN
# 4     harshit     NaN               NaN  21.0   NaN   NaN  21.0
# 5       yusra    65.0              56.0  22.0  65.0  56.0  22.0
# 6       omkar    45.0              67.0   NaN  45.0  67.0   NaN
# 7   tejashree    80.0              45.0  24.0  80.0  45.0  24.0
# 8      khushi    70.0              67.0   NaN  70.0  67.0   NaN
# 9    vrishali     NaN               NaN  22.0   NaN   NaN  22.0
# 10     mahesh     NaN               NaN  22.0   NaN   NaN  80.0
# 11    utkarsh     NaN               NaN  20.0  80.0   NaN  90.0
# 12     sachin     NaN               NaN  23.0   NaN   NaN  80.0
# 13     vishal     NaN               NaN  23.0  80.0  78.0   NaN
# ...

# %%
list1=list(df.columns)

# %%
list1
# Out:
# ['Name', 'Python', 'Machine Learning', 'Age', 'AI', 'NLP', 'Cv']

# %%
list1=list1[1:]

# %%
for i in list1:
    df[i]=df[i].astype("int")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-17-b19da84bf6e0> in <module>
#       1 for i in list1:
# ----> 2     df[i]=df[i].astype("int")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     448
#     449     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 450         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     451
#     452     def convert(
#
# ...

# %%
for i in list1:
    df[i].fillna(round(df[i].mean(),2),inplace=True)

# %%
#for single column
df["Python"]=df["Python"].astype("float")

# %%
df["Python"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              19 non-null     object
#  1   Python            19 non-null     float64
#  2   Machine Learning  19 non-null     float64
#  3   Age               19 non-null     float64
#  4   AI                19 non-null     float64
#  5   NLP               19 non-null     float64
#  6   Cv                19 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.2+ KB

# %%
df = pd.read_csv("data2.csv")
df
# Out:
#          Name   Python Machine Learning      Age       AI      NLP       Cv
# 0      Sakshi       90                ?       23       90        ?       23
# 1      rajesh  missing               89      NaN  missing       89      NaN
# 2      pratik       78               78        ?       78       78        ?
# 3       mayur      NaN              NaN  missing      NaN      NaN  missing
# 4     harshit  missing              NaN       21  missing      NaN       21
# 5       yusra       65               56       22       65       56       22
# 6       omkar       45               67        ?       45       67        ?
# 7   tejashree       80               45       24       80       45       24
# 8      khushi       70               67  missing       70       67  missing
# 9    vrishali      NaN              NaN       22      NaN      NaN       22
# 10     mahesh        $          missing       22        ?        ?       80
# ...

# %%
df["Machine Learning"]=pd.to_numeric(df["Machine Learning"],errors="coerce")

# %%
df["Python"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df
# Out:
#          Name  Python  Machine Learning      Age       AI      NLP       Cv
# 0      Sakshi    90.0               NaN       23       90        ?       23
# 1      rajesh     NaN              89.0      NaN  missing       89      NaN
# 2      pratik    78.0              78.0        ?       78       78        ?
# 3       mayur     NaN               NaN  missing      NaN      NaN  missing
# 4     harshit     NaN               NaN       21  missing      NaN       21
# 5       yusra    65.0              56.0       22       65       56       22
# 6       omkar    45.0              67.0        ?       45       67        ?
# 7   tejashree    80.0              45.0       24       80       45       24
# 8      khushi    70.0              67.0  missing       70       67  missing
# 9    vrishali     NaN               NaN       22      NaN      NaN       22
# 10     mahesh     NaN               NaN       22        ?        ?       80
# ...

# %%
df["Age"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df
# Out:
#          Name  Python  Machine Learning   Age       AI      NLP       Cv
# 0      Sakshi    90.0               NaN  90.0       90        ?       23
# 1      rajesh     NaN              89.0   NaN  missing       89      NaN
# 2      pratik    78.0              78.0  78.0       78       78        ?
# 3       mayur     NaN               NaN   NaN      NaN      NaN  missing
# 4     harshit     NaN               NaN   NaN  missing      NaN       21
# 5       yusra    65.0              56.0  65.0       65       56       22
# 6       omkar    45.0              67.0  45.0       45       67        ?
# 7   tejashree    80.0              45.0  80.0       80       45       24
# 8      khushi    70.0              67.0  70.0       70       67  missing
# 9    vrishali     NaN               NaN   NaN      NaN      NaN       22
# 10     mahesh     NaN               NaN   NaN        ?        ?       80
# 11    utkarsh     NaN               NaN   NaN       80  missing       90
# ...

# %%
df["AI"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df
# Out:
#          Name  Python  Machine Learning   Age    AI      NLP       Cv
# 0      Sakshi    90.0               NaN  90.0  90.0        ?       23
# 1      rajesh     NaN              89.0   NaN   NaN       89      NaN
# 2      pratik    78.0              78.0  78.0  78.0       78        ?
# 3       mayur     NaN               NaN   NaN   NaN      NaN  missing
# 4     harshit     NaN               NaN   NaN   NaN      NaN       21
# 5       yusra    65.0              56.0  65.0  65.0       56       22
# 6       omkar    45.0              67.0  45.0  45.0       67        ?
# 7   tejashree    80.0              45.0  80.0  80.0       45       24
# 8      khushi    70.0              67.0  70.0  70.0       67  missing
# 9    vrishali     NaN               NaN   NaN   NaN      NaN       22
# 10     mahesh     NaN               NaN   NaN   NaN        ?       80
# 11    utkarsh     NaN               NaN   NaN   NaN  missing       90
# ...

# %%
df["NLP"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df
# Out:
#          Name  Python  Machine Learning   Age    AI   NLP       Cv
# 0      Sakshi    90.0               NaN  90.0  90.0  90.0       23
# 1      rajesh     NaN              89.0   NaN   NaN   NaN      NaN
# 2      pratik    78.0              78.0  78.0  78.0  78.0        ?
# 3       mayur     NaN               NaN   NaN   NaN   NaN  missing
# 4     harshit     NaN               NaN   NaN   NaN   NaN       21
# 5       yusra    65.0              56.0  65.0  65.0  65.0       22
# 6       omkar    45.0              67.0  45.0  45.0  45.0        ?
# 7   tejashree    80.0              45.0  80.0  80.0  80.0       24
# 8      khushi    70.0              67.0  70.0  70.0  70.0  missing
# 9    vrishali     NaN               NaN   NaN   NaN   NaN       22
# 10     mahesh     NaN               NaN   NaN   NaN   NaN       80
# 11    utkarsh     NaN               NaN   NaN   NaN   NaN       90
# 12     sachin     NaN               NaN   NaN   NaN   NaN       80
# ...

# %%
df["Cv"]=pd.to_numeric(df.Python,errors="coerce")

# %%
df
# Out:
#          Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0      Sakshi    90.0               NaN  90.0  90.0  90.0  90.0
# 1      rajesh     NaN              89.0   NaN   NaN   NaN   NaN
# 2      pratik    78.0              78.0  78.0  78.0  78.0  78.0
# 3       mayur     NaN               NaN   NaN   NaN   NaN   NaN
# 4     harshit     NaN               NaN   NaN   NaN   NaN   NaN
# 5       yusra    65.0              56.0  65.0  65.0  65.0  65.0
# 6       omkar    45.0              67.0  45.0  45.0  45.0  45.0
# 7   tejashree    80.0              45.0  80.0  80.0  80.0  80.0
# 8      khushi    70.0              67.0  70.0  70.0  70.0  70.0
# 9    vrishali     NaN               NaN   NaN   NaN   NaN   NaN
# 10     mahesh     NaN               NaN   NaN   NaN   NaN   NaN
# 11    utkarsh     NaN               NaN   NaN   NaN   NaN   NaN
# 12     sachin     NaN               NaN   NaN   NaN   NaN   NaN
# 13     vishal     NaN               NaN   NaN   NaN   NaN   NaN
# ...

# %%
df["Python"]=df["Python"].astype("float")

# %%
df["Machine Learning"]=df["Machine Learning"].astype("float")

# %%
df["Age"]=df["Age"].astype("float")

# %%
df["AI"]=df["AI"].astype("float")

# %%
df["NLP"]=df["NLP"].astype("float")

# %%
df["Cv"]=df["Cv"].astype("float")

# %%
df
# Out:
#          Name  Python  Machine Learning   Age    AI   NLP    Cv
# 0      Sakshi    90.0               NaN  90.0  90.0  90.0  90.0
# 1      rajesh     NaN              89.0   NaN   NaN   NaN   NaN
# 2      pratik    78.0              78.0  78.0  78.0  78.0  78.0
# 3       mayur     NaN               NaN   NaN   NaN   NaN   NaN
# 4     harshit     NaN               NaN   NaN   NaN   NaN   NaN
# 5       yusra    65.0              56.0  65.0  65.0  65.0  65.0
# 6       omkar    45.0              67.0  45.0  45.0  45.0  45.0
# 7   tejashree    80.0              45.0  80.0  80.0  80.0  80.0
# 8      khushi    70.0              67.0  70.0  70.0  70.0  70.0
# 9    vrishali     NaN               NaN   NaN   NaN   NaN   NaN
# 10     mahesh     NaN               NaN   NaN   NaN   NaN   NaN
# 11    utkarsh     NaN               NaN   NaN   NaN   NaN   NaN
# 12     sachin     NaN               NaN   NaN   NaN   NaN   NaN
# 13     vishal     NaN               NaN   NaN   NaN   NaN   NaN
# ...

# %%
pmean=df["Python"].mean()

# %%
mlmean=df["Machine Learning"].mean()

# %%
agemean=df["Age"].mean()

# %%
aimean=df["AI"].mean()

# %%
nlpmean=df["NLP"].mean()

# %%
cvmean=df["Cv"].mean()

# %%
df["Python"].fillna(pmean,inplace=True)

# %%
df["Machine Learning"].fillna(mlmean,inplace=True)

# %%
df["AI"].fillna(aimean,inplace=True)

# %%
df["NLP"].fillna(nlpmean,inplace=True)

# %%
df["Age"].fillna(agemean,inplace=True)

# %%
df["Cv"].fillna(cvmean,inplace=True)

# %%
df
# Out:
#          Name     Python  Machine Learning        Age         AI        NLP  \
# 0      Sakshi  90.000000         68.857143  90.000000  90.000000  90.000000
# 1      rajesh  71.333333         89.000000  71.333333  71.333333  71.333333
# 2      pratik  78.000000         78.000000  78.000000  78.000000  78.000000
# 3       mayur  71.333333         68.857143  71.333333  71.333333  71.333333
# 4     harshit  71.333333         68.857143  71.333333  71.333333  71.333333
# 5       yusra  65.000000         56.000000  65.000000  65.000000  65.000000
# 6       omkar  45.000000         67.000000  45.000000  45.000000  45.000000
# 7   tejashree  80.000000         45.000000  80.000000  80.000000  80.000000
# 8      khushi  70.000000         67.000000  70.000000  70.000000  70.000000
# 9    vrishali  71.333333         68.857143  71.333333  71.333333  71.333333
# 10     mahesh  71.333333         68.857143  71.333333  71.333333  71.333333
# ...
